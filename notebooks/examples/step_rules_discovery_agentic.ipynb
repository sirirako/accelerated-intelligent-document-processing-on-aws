# %% [markdown]
# # Rules Discovery Using Agentic Methods
#
# This notebook demonstrates rules extraction from policy documents using both **agentic** and **traditional** methods, with a direct comparison.
#
# The agentic method uses Strands Agent for a self-correcting mechanism working against Pydantic models internally to ensure schema adherence.
#
# **Important:** The agentic method only works with higher intelligence models that support tool use. Recommended model family is Anthropic Claude.
#
# **Inputs:**
# - A policy document (PDF or image)
# - Discovery configuration (model, prompts, agentic toggle)
#
# **Outputs:**
# - Structured rules in `rule_classes` format
# - Comparison of agentic vs traditional extraction

# %% [markdown]
# ## 1. Setup

# %%
ROOTDIR = "../.."
# %pip install -q -e "{ROOTDIR}/lib/idp_common_pkg[agentic-extraction]"
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from idp_common.extraction.agentic_idp import structured_output

# %%
import os, json, yaml, time, logging, boto3
from pathlib import Path
from idp_common.discovery import RulesDiscovery
from idp_common.config.models import IDPConfig

logging.basicConfig(level=logging.WARNING)
logging.getLogger('idp_common.discovery').setLevel(logging.INFO)
logging.getLogger('idp_common.bedrock').setLevel(logging.INFO)
logging.getLogger('idp_common.extraction.agentic_idp').setLevel(logging.INFO)
print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %%
POLICY_PDF_PATH = f"{ROOTDIR}/samples/rule-validation/NCCI Medicare Policy Manual.pdf"
os.environ['AWS_REGION'] = boto3.session.Session().region_name or 'us-east-1'
os.environ['METRIC_NAMESPACE'] = 'IDP-Modular-Pipeline'
region = os.environ['AWS_REGION']
print(f"AWS Region: {region}")

policy_path = Path(POLICY_PDF_PATH)
if not policy_path.exists():
    print(f"ERROR: Policy document not found at {POLICY_PDF_PATH}")
else:
    print(f"Policy document: {policy_path.name} ({policy_path.stat().st_size / (1024*1024):.1f} MB)")
# Out:
# AWS Region: us-east-1
# Policy document: NCCI Medicare Policy Manual.pdf (0.2 MB)

# %%
config_dir = Path("config")
CONFIG = {}
for cf in ["rules_discovery.yaml"]:
    cp = config_dir / cf
    if cp.exists():
        with open(cp, 'r') as f:
            CONFIG.update(yaml.safe_load(f))
        print(f"Loaded {cf}")
print(f"Config sections: {list(CONFIG.keys())}")
# Out:
# Loaded rules_discovery.yaml
# Config sections: ['discovery']

# %% [markdown]
# ## Agentic Rules Discovery
# ### 2. Configure - with Agentic

# %%
# Enable agentic mode — preserve other agentic settings (review_agent, review_agent_model) from YAML
CONFIG["discovery"]["rules"].setdefault("agentic", {})["enabled"] = True
CONFIG["discovery"]["rules"]["model"] = "us.anthropic.claude-opus-4-6-v1"
# CONFIG["discovery"]["rules"]["model"] = "us.anthropic.claude-opus-4-6-v1:1m"

rc = CONFIG['discovery']['rules']
print(f"Model: {rc['model']}")
print(f"Agentic: {rc['agentic']}")
print(f"Temperature: {rc.get('temperature')}")
print(f"Max Tokens: {rc.get('max_tokens')}")
# Out:
# Model: us.anthropic.claude-opus-4-6
# Agentic: {'enabled': True, 'review_agent': True, 'review_agent_model': 'us.anthropic.claude-sonnet-4-6'}
# Temperature: 0.0
# Max Tokens: 64000

# %% [markdown]
# ### 3. Run Agentic Rules Discovery

# %%
config_agentic = IDPConfig(**CONFIG)
discovery_agentic = RulesDiscovery(input_bucket="unused", input_prefix="unused", region=region, config=config_agentic)

print(f"Model: {discovery_agentic.rules_config.model}")
print(f"Agentic: {discovery_agentic.rules_config.agentic.enabled}")
print("Extracting rules...\n")

t0 = time.time()
result_agentic = discovery_agentic.discovery_rules_from_document_local(POLICY_PDF_PATH)
agentic_time = time.time() - t0

print(f"\nCompleted in {agentic_time:.1f}s | Status: {result_agentic['status']} | Rule classes: {len(result_agentic['rules'])}")
# Out:
# INFO:idp_common.discovery.rules_discovery:Extracting rules from local document: ../../samples/rule-validation/NCCI Medicare Policy Manual.pdf
# INFO:idp_common.discovery.rules_discovery:Document size: 170691 bytes
# INFO:idp_common.discovery.rules_discovery:Rules discovery using model: us.anthropic.claude-opus-4-6
# INFO:idp_common.discovery.rules_discovery:Using agentic rule discovery with structured_output()
# Model: us.anthropic.claude-opus-4-6
# Agentic: True
# Extracting rules...
#
# {"level":"INFO","location":"_build_model_config:690","message":"Setting max_tokens for model","timestamp":"2026-02-19 22:43:59,099+0000","service":"agentic_idp","taskName":"Task-41","max_tokens":64000,"model_id":"us.anthropic.claude-opus-4-6","model_max_tokens":64000}
# INFO:agentic_idp:Setting max_tokens for model
# ERROR:idp_common.utils.bedrock_utils:Bedrock invocation error
# ERROR:idp_common.discovery.rules_discovery:Agentic rule discovery failed: An error occurred (ValidationException) when calling the ConverseStream operation: The provided model identifier is invalid.
# Traceback (most recent call last):
#   File "/home/ubuntu/efs/EFSSpace/Workspace/rule_validation_research/genaiic-idp-accelerator/lib/idp_common_pkg/idp_common/discovery/rules_discovery.py", line 396, in _extract_rules_agentic
#     structured_data, response_with_metering = structured_output(
#                                               ^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/efs/EFSSpace/Workspace/rule_validation_research/genaiic-idp-accelerator/lib/idp_common_pkg/idp_common/extraction/agentic_idp.py", line 1340, in structured_output
#     raise exception
#   File "/home/ubuntu/efs/EFSSpace/Workspace/rule_validation_research/genaiic-idp-accelerator/lib/idp_common_pkg/idp_common/extraction/agentic_idp.py", line 1314, in run_in_new_loop
#     result = new_loop.run_until_complete(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/asyncio/base_events.py", line 691, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/home/ubuntu/efs/EFSSpace/Workspace/rule_validation_research/genaiic-idp-accelerator/lib/idp_common_pkg/idp_common/extraction/agentic_idp.py", line 1104, in structured_output_async
#     response, result = await _invoke_agent_for_extraction(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/efs/EFSSpace/Workspace/rule_validation_research/genaiic-idp-accelerator/lib/idp_common_pkg/idp_common/extraction/agentic_idp.py", line 864, in _invoke_agent_for_extraction
#     response = await invoke_agent_with_retry(agent=agent, input=prompt_content)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/efs/EFSSpace/Workspace/rule_validation_research/genaiic-idp-accelerator/lib/idp_common_pkg/idp_common/utils/bedrock_utils.py", line 95, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/efs/EFSSpace/Workspace/rule_validation_research/genaiic-idp-accelerator/lib/idp_common_pkg/idp_common/extraction/agentic_idp.py", line 558, in invoke_agent_with_retry
#     return await agent.invoke_async(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/agent/agent.py", line 470, in invoke_async
#     async for event in events:
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/agent/agent.py", line 666, in stream_async
#     async for event in events:
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/agent/agent.py", line 746, in _run_loop
#     async for event in events:
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/agent/agent.py", line 794, in _execute_event_loop_cycle
#     async for event in events:
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/event_loop/event_loop.py", line 152, in event_loop_cycle
#     async for model_event in model_events:
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/event_loop/event_loop.py", line 391, in _handle_model_execution
#     raise e
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/event_loop/event_loop.py", line 337, in _handle_model_execution
#     async for event in stream_messages(
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/event_loop/streaming.py", line 441, in stream_messages
#     async for event in process_stream(chunks, start_time):
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/event_loop/streaming.py", line 388, in process_stream
#     async for chunk in chunks:
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/models/bedrock.py", line 633, in stream
#     await task
#   File "/usr/local/lib/python3.12/asyncio/threads.py", line 25, in to_thread
#     return await loop.run_in_executor(None, func_call)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/opentelemetry/instrumentation/threading/__init__.py", line 171, in wrapped_func
#     return original_func(*func_args, **func_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/models/bedrock.py", line 754, in _stream
#     raise e
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/models/bedrock.py", line 669, in _stream
#     response = self.client.converse_stream(**request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/botocore/client.py", line 602, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/botocore/context.py", line 123, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/botocore/client.py", line 1078, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.ValidationException: An error occurred (ValidationException) when calling the ConverseStream operation: The provided model identifier is invalid.
# └ Bedrock region: us-east-1
# └ Model id: us.anthropic.claude-opus-4-6
# ERROR:idp_common.discovery.rules_discovery:Error extracting rules from ../../samples/rule-validation/NCCI Medicare Policy Manual.pdf: An error occurred (ValidationException) when calling the ConverseStream operation: The provided model identifier is invalid.
# Traceback (most recent call last):
#   File "/home/ubuntu/efs/EFSSpace/Workspace/rule_validation_research/genaiic-idp-accelerator/lib/idp_common_pkg/idp_common/discovery/rules_discovery.py", line 187, in discovery_rules_from_document_local
#     extracted_rules = self._extract_rules(file_in_bytes, file_extension)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/efs/EFSSpace/Workspace/rule_validation_research/genaiic-idp-accelerator/lib/idp_common_pkg/idp_common/discovery/rules_discovery.py", line 241, in _extract_rules
#     return self._extract_rules_agentic(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/efs/EFSSpace/Workspace/rule_validation_research/genaiic-idp-accelerator/lib/idp_common_pkg/idp_common/discovery/rules_discovery.py", line 396, in _extract_rules_agentic
#     structured_data, response_with_metering = structured_output(
#                                               ^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/efs/EFSSpace/Workspace/rule_validation_research/genaiic-idp-accelerator/lib/idp_common_pkg/idp_common/extraction/agentic_idp.py", line 1340, in structured_output
#     raise exception
#   File "/home/ubuntu/efs/EFSSpace/Workspace/rule_validation_research/genaiic-idp-accelerator/lib/idp_common_pkg/idp_common/extraction/agentic_idp.py", line 1314, in run_in_new_loop
#     result = new_loop.run_until_complete(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/asyncio/base_events.py", line 691, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/home/ubuntu/efs/EFSSpace/Workspace/rule_validation_research/genaiic-idp-accelerator/lib/idp_common_pkg/idp_common/extraction/agentic_idp.py", line 1104, in structured_output_async
#     response, result = await _invoke_agent_for_extraction(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/efs/EFSSpace/Workspace/rule_validation_research/genaiic-idp-accelerator/lib/idp_common_pkg/idp_common/extraction/agentic_idp.py", line 864, in _invoke_agent_for_extraction
#     response = await invoke_agent_with_retry(agent=agent, input=prompt_content)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/efs/EFSSpace/Workspace/rule_validation_research/genaiic-idp-accelerator/lib/idp_common_pkg/idp_common/utils/bedrock_utils.py", line 95, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/efs/EFSSpace/Workspace/rule_validation_research/genaiic-idp-accelerator/lib/idp_common_pkg/idp_common/extraction/agentic_idp.py", line 558, in invoke_agent_with_retry
#     return await agent.invoke_async(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/agent/agent.py", line 470, in invoke_async
#     async for event in events:
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/agent/agent.py", line 666, in stream_async
#     async for event in events:
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/agent/agent.py", line 746, in _run_loop
#     async for event in events:
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/agent/agent.py", line 794, in _execute_event_loop_cycle
#     async for event in events:
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/event_loop/event_loop.py", line 152, in event_loop_cycle
#     async for model_event in model_events:
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/event_loop/event_loop.py", line 391, in _handle_model_execution
#     raise e
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/event_loop/event_loop.py", line 337, in _handle_model_execution
#     async for event in stream_messages(
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/event_loop/streaming.py", line 441, in stream_messages
#     async for event in process_stream(chunks, start_time):
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/event_loop/streaming.py", line 388, in process_stream
#     async for chunk in chunks:
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/models/bedrock.py", line 633, in stream
#     await task
#   File "/usr/local/lib/python3.12/asyncio/threads.py", line 25, in to_thread
#     return await loop.run_in_executor(None, func_call)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/opentelemetry/instrumentation/threading/__init__.py", line 171, in wrapped_func
#     return original_func(*func_args, **func_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/models/bedrock.py", line 754, in _stream
#     raise e
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/models/bedrock.py", line 669, in _stream
#     response = self.client.converse_stream(**request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/botocore/client.py", line 602, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/botocore/context.py", line 123, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/botocore/client.py", line 1078, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.ValidationException: An error occurred (ValidationException) when calling the ConverseStream operation: The provided model identifier is invalid.
# └ Bedrock region: us-east-1
# └ Model id: us.anthropic.claude-opus-4-6
# ---------------------------------------------------------------------------
# ValidationException                       Traceback (most recent call last)
# File ~/efs/EFSSpace/Workspace/rule_validation_research/genaiic-idp-accelerator/lib/idp_common_pkg/idp_common/discovery/rules_discovery.py:187, in RulesDiscovery.discovery_rules_from_document_local(self, file_path)
#     185 logger.info(f"Document size: {len(file_in_bytes)} bytes")
# --> 187 extracted_rules = self._extract_rules(file_in_bytes, file_extension)
#     189 if extracted_rules is None:
#
# File ~/efs/EFSSpace/Workspace/rule_validation_research/genaiic-idp-accelerator/lib/idp_common_pkg/idp_common/discovery/rules_discovery.py:241, in RulesDiscovery._extract_rules(self, document_content, file_extension, max_retries)
#     240 if self.rules_config.agentic.enabled:
# --> 241     return self._extract_rules_agentic(
#     242         document_content=document_content,
#     243         file_extension=file_extension,
#     244         model_id=model_id,
#     245         system_prompt=system_prompt,
#     246         user_prompt=user_prompt,
#     247         max_tokens=max_tokens,
#     248     )
#     250 # ── Traditional path ──────────────────────────────────────────
#
# File ~/efs/EFSSpace/Workspace/rule_validation_research/genaiic-idp-accelerator/lib/idp_common_pkg/idp_common/discovery/rules_discovery.py:396, in RulesDiscovery._extract_rules_agentic(self, document_content, file_extension, model_id, system_prompt, user_prompt, max_tokens)
#     395 try:
# --> 396     structured_data, response_with_metering = structured_output(
#     397         model_id=model_id,
#     398         data_format=RuleDiscoveryOutput,
#     399         prompt=message_prompt,
#     400         page_images=None,  # PDF sent as document content, not page images
#     401         config=rules_config_override,
#     402         context="RulesDiscovery",
#     403         custom_instruction=user_prompt,
#     404         system_prompt=system_prompt,
#     405     )
#     407     # Convert Pydantic models → list of dicts (existing rule_classes format)
#
# File ~/efs/EFSSpace/Workspace/rule_validation_research/genaiic-idp-accelerator/lib/idp_common_pkg/idp_common/extraction/agentic_idp.py:1340, in structured_output(model_id, data_format, prompt, existing_data, system_prompt, custom_instruction, page_images, context, config, max_retries, connect_timeout, read_timeout)
#    1339 if exception:
# -> 1340     raise exception
#    1341 assert result is not None  # For type checker
#
# File ~/efs/EFSSpace/Workspace/rule_validation_research/genaiic-idp-accelerator/lib/idp_common_pkg/idp_common/extraction/agentic_idp.py:1314, in structured_output.<locals>.run_in_new_loop()
#    1313 try:
# -> 1314     result = new_loop.run_until_complete(
#    1315         structured_output_async(
#    1316             model_id=model_id,
#    1317             data_format=data_format,
#    1318             prompt=prompt,
#    1319             existing_data=existing_data,
#    1320             system_prompt=system_prompt,
#    1321             custom_instruction=custom_instruction,
#    1322             config=config,
#    1323             context=context,
#    1324             max_retries=max_retries,
#    1325             connect_timeout=connect_timeout,
#    1326             read_timeout=read_timeout,
#    1327             page_images=page_images,
#    1328         )
#    1329     )
#    1330 except Exception as e:
#
# File /usr/local/lib/python3.12/asyncio/base_events.py:691, in BaseEventLoop.run_until_complete(self, future)
#     689     raise RuntimeError('Event loop stopped before Future completed.')
# --> 691 return future.result()
#
# File ~/efs/EFSSpace/Workspace/rule_validation_research/genaiic-idp-accelerator/lib/idp_common_pkg/idp_common/extraction/agentic_idp.py:1104, in structured_output_async(model_id, data_format, prompt, existing_data, system_prompt, custom_instruction, config, page_images, context, max_retries, connect_timeout, read_timeout, max_tokens)
#    1102     agent.state.set("current_extraction", existing_data.model_dump(mode="json"))
# -> 1104 response, result = await _invoke_agent_for_extraction(
#    1105     agent=agent,
#    1106     prompt_content=prompt_content,
#    1107     data_format=data_format,
#    1108     max_extraction_retries=3,
#    1109 )
#    1111 # Accumulate token usage
#
# File ~/efs/EFSSpace/Workspace/rule_validation_research/genaiic-idp-accelerator/lib/idp_common_pkg/idp_common/extraction/agentic_idp.py:864, in _invoke_agent_for_extraction(agent, prompt_content, data_format, max_extraction_retries)
#     862 for attempt in range(max_extraction_retries):
#     863     # invoke_agent_with_retry already handles network errors and throttling
# --> 864     response = await invoke_agent_with_retry(agent=agent, input=prompt_content)
#     865     logger.debug("Agent response received")
#
# File ~/efs/EFSSpace/Workspace/rule_validation_research/genaiic-idp-accelerator/lib/idp_common_pkg/idp_common/utils/bedrock_utils.py:95, in async_exponential_backoff_retry.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      94 try:
# ---> 95     return await func(*args, **kwargs)
#      96 except botocore.exceptions.ClientError as e:
#
# File ~/efs/EFSSpace/Workspace/rule_validation_research/genaiic-idp-accelerator/lib/idp_common_pkg/idp_common/extraction/agentic_idp.py:558, in invoke_agent_with_retry(input, agent)
#     551 @async_exponential_backoff_retry(
#     552     max_retries=50,
#     553     initial_delay=5,
#    (...)    556 )
#     557 async def invoke_agent_with_retry(input: AgentInput, agent: Agent):
# --> 558     return await agent.invoke_async(input)
#
# File ~/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/agent/agent.py:470, in Agent.invoke_async(self, prompt, invocation_state, structured_output_model, **kwargs)
#     467 events = self.stream_async(
#     468     prompt, invocation_state=invocation_state, structured_output_model=structured_output_model, **kwargs
#     469 )
# --> 470 async for event in events:
#     471     _ = event
#
# File ~/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/agent/agent.py:666, in Agent.stream_async(self, prompt, invocation_state, structured_output_model, **kwargs)
#     664 events = self._run_loop(messages, merged_state, structured_output_model)
# --> 666 async for event in events:
#     667     event.prepare(invocation_state=merged_state)
#
# File ~/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/agent/agent.py:746, in Agent._run_loop(self, messages, invocation_state, structured_output_model)
#     745 events = self._execute_event_loop_cycle(invocation_state, structured_output_context)
# --> 746 async for event in events:
#     747     # Signal from the model provider that the message sent by the user should be redacted,
#     748     # likely due to a guardrail.
#     749     if (
#     750         isinstance(event, ModelStreamChunkEvent)
#     751         and event.chunk
#     752         and event.chunk.get("redactContent")
#     753         and event.chunk["redactContent"].get("redactUserContentMessage")
#     754     ):
#
# File ~/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/agent/agent.py:794, in Agent._execute_event_loop_cycle(self, invocation_state, structured_output_context)
#     789 events = event_loop_cycle(
#     790     agent=self,
#     791     invocation_state=invocation_state,
#     792     structured_output_context=structured_output_context,
#     793 )
# --> 794 async for event in events:
#     795     yield event
#
# File ~/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/event_loop/event_loop.py:152, in event_loop_cycle(agent, invocation_state, structured_output_context)
#     149 model_events = _handle_model_execution(
#     150     agent, cycle_span, cycle_trace, invocation_state, tracer, structured_output_context
#     151 )
# --> 152 async for model_event in model_events:
#     153     if not isinstance(model_event, ModelStopReason):
#
# File ~/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/event_loop/event_loop.py:391, in _handle_model_execution(agent, cycle_span, cycle_trace, invocation_state, tracer, structured_output_context)
#     390             else:
# --> 391                 raise e
#     393 try:
#     394     # Add message in trace and mark the end of the stream messages trace
#
# File ~/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/event_loop/event_loop.py:337, in _handle_model_execution(agent, cycle_span, cycle_trace, invocation_state, tracer, structured_output_context)
#     336 try:
# --> 337     async for event in stream_messages(
#     338         agent.model, agent.system_prompt, agent.messages, tool_specs, structured_output_context.tool_choice
#     339     ):
#     340         yield event
#
# File ~/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/event_loop/streaming.py:441, in stream_messages(model, system_prompt, messages, tool_specs, tool_choice)
#     439 chunks = model.stream(messages, tool_specs if tool_specs else None, system_prompt, tool_choice=tool_choice)
# --> 441 async for event in process_stream(chunks, start_time):
#     442     yield event
#
# File ~/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/event_loop/streaming.py:388, in process_stream(chunks, start_time)
#     386 metrics: Metrics = Metrics(latencyMs=0, timeToFirstByteMs=0)
# --> 388 async for chunk in chunks:
#     389     # Track first byte time when we get first content
#     390     if first_byte_time is None and ("contentBlockDelta" in chunk or "contentBlockStart" in chunk):
#
# File ~/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/models/bedrock.py:633, in BedrockModel.stream(self, messages, tool_specs, system_prompt, tool_choice, **kwargs)
#     631     yield event
# --> 633 await task
#
# File /usr/local/lib/python3.12/asyncio/threads.py:25, in to_thread(func, *args, **kwargs)
#      24 func_call = functools.partial(ctx.run, func, *args, **kwargs)
# ---> 25 return await loop.run_in_executor(None, func_call)
#
# File /usr/local/lib/python3.12/concurrent/futures/thread.py:59, in _WorkItem.run(self)
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#
# File ~/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/opentelemetry/instrumentation/threading/__init__.py:171, in ThreadingInstrumentor.__wrap_thread_pool_submit.<locals>.wrapped_func(*func_args, **func_kwargs)
#     170     token = context.attach(otel_context)
# --> 171     return original_func(*func_args, **func_kwargs)
#     172 finally:
#
# File ~/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/models/bedrock.py:754, in BedrockModel._stream(self, callback, messages, tool_specs, system_prompt, tool_choice)
#     748         add_exception_note(
#     749             e,
#     750             "└ For more information see "
#     751             "https://strandsagents.com/latest/user-guide/concepts/model-providers/amazon-bedrock/#on-demand-throughput-isnt-supported",
#     752         )
# --> 754     raise e
#     756 finally:
#
# File ~/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/strands/models/bedrock.py:669, in BedrockModel._stream(self, callback, messages, tool_specs, system_prompt, tool_choice)
#     668 if streaming:
# --> 669     response = self.client.converse_stream(**request)
#     670     # Track tool use events to fix stopReason for streaming responses
#
# File ~/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/botocore/client.py:602, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     601 # The "self" in this scope is referring to the BaseClient.
# --> 602 return self._make_api_call(operation_name, kwargs)
#
# File ~/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File ~/Workspace/rule_validation_research/genaiic-idp-accelerator/.venv/lib/python3.12/site-packages/botocore/client.py:1078, in BaseClient._make_api_call(self, operation_name, api_params)
#    1077     error_class = self.exceptions.from_code(error_code)
# -> 1078     raise error_class(parsed_response, operation_name)
#    1079 else:
#
# ValidationException: An error occurred (ValidationException) when calling the ConverseStream operation: The provided model identifier is invalid.
# └ Bedrock region: us-east-1
# └ Model id: us.anthropic.claude-opus-4-6
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[26], line 9
#       6 print("Extracting rules...\n")
#       8 t0 = time.time()
# ----> 9 result_agentic = discovery_agentic.discovery_rules_from_document_local(POLICY_PDF_PATH)
#      10 agentic_time = time.time() - t0
#      12 print(f"\nCompleted in {agentic_time:.1f}s | Status: {result_agentic['status']} | Rule classes: {len(result_agentic['rules'])}")
#
# File ~/efs/EFSSpace/Workspace/rule_validation_research/genaiic-idp-accelerator/lib/idp_common_pkg/idp_common/discovery/rules_discovery.py:198, in RulesDiscovery.discovery_rules_from_document_local(self, file_path)
#     194 except Exception as e:
#     195     logger.error(
#     196         f"Error extracting rules from {file_path}: {e}", exc_info=True
#     197     )
# --> 198     raise Exception(
#     199         f"Failed to extract rules from {file_path}: {str(e)}"
#     200     )
#
# Exception: Failed to extract rules from ../../samples/rule-validation/NCCI Medicare Policy Manual.pdf: An error occurred (ValidationException) when calling the ConverseStream operation: The provided model identifier is invalid.

# %% [markdown]
# ### 4. Display Agentic Results

# %%
rules_agentic = result_agentic['rules']
total_agentic = 0
for i, rc in enumerate(rules_agentic):
    rp = rc.get('rule_properties', {})
    total_agentic += len(rp)
    print(f"\n[{rc.get('x-aws-idp-rule-type','?')}] {len(rp)} rules")
    for rid, rdef in list(rp.items())[:3]:
        d = rdef.get('description','')[:100]
        print(f"  {rid} (p.{rdef.get('page','?')}): {d}")
    if len(rp) > 3:
        print(f"  ... +{len(rp)-3} more")
print(f"\nTOTAL: {len(rules_agentic)} classes, {total_agentic} rules")
# Out:
# [policy_rules] 60 rules
#   report_most_specific_code (p.V-3): Is the most specific HCPCS/CPT code that describes the procedure performed reported?
#   report_code_only_if_all_services_performed (p.V-3): Is a HCPCS/CPT code reported only if ALL services described by the code are performed?
#   no_multiple_codes_if_single_exists (p.V-3): Are multiple HCPCS/CPT codes NOT reported when a single HCPCS/CPT code exists that describes the ser
#   ... +57 more
#
# TOTAL: 1 classes, 60 rules

# %% [markdown]
# ### 5. Save Agentic Results

# %%
data_dir = Path(".data/step_rules_discovery_agentic")
data_dir.mkdir(parents=True, exist_ok=True)
with open(data_dir / "rule_classes_agentic.json", 'w') as f:
    json.dump(rules_agentic, f, indent=2)
print(f"Saved agentic rules to {data_dir}")
# Out:
# Saved agentic rules to .data/step_rules_discovery_agentic

# %% [markdown]
# ---
# ## Traditional Rules Discovery
# ### 2. Configure - without Agentic

# %%
# Disable agentic mode for traditional comparison run
CONFIG["discovery"]["rules"].setdefault("agentic", {})["enabled"] = False
CONFIG["discovery"]["rules"]["model"] = "us.anthropic.claude-sonnet-4-20250514-v1:0"

rc = CONFIG['discovery']['rules']
print(f"Model: {rc['model']}")
print(f"Agentic: {rc['agentic']}")

# %% [markdown]
# ### 3. Run Traditional Rules Discovery

# %%
config_traditional = IDPConfig(**CONFIG)
discovery_traditional = RulesDiscovery(input_bucket="unused", input_prefix="unused", region=region, config=config_traditional)

print(f"Model: {discovery_traditional.rules_config.model}")
print(f"Agentic: {discovery_traditional.rules_config.agentic.enabled}")
print("Extracting rules...\n")

t0 = time.time()
result_traditional = discovery_traditional.discovery_rules_from_document_local(POLICY_PDF_PATH)
traditional_time = time.time() - t0

print(f"\nCompleted in {traditional_time:.1f}s | Status: {result_traditional['status']} | Rule classes: {len(result_traditional['rules'])}")

# %% [markdown]
# ### 4. Display Traditional Results

# %%
rules_traditional = result_traditional['rules']
total_traditional = 0
for i, rc in enumerate(rules_traditional):
    rp = rc.get('rule_properties', {})
    total_traditional += len(rp)
    print(f"\n[{rc.get('x-aws-idp-rule-type','?')}] {len(rp)} rules")
    for rid, rdef in list(rp.items())[:3]:
        d = rdef.get('description','')[:100]
        print(f"  {rid} (p.{rdef.get('page','?')}): {d}")
    if len(rp) > 3:
        print(f"  ... +{len(rp)-3} more")
print(f"\nTOTAL: {len(rules_traditional)} classes, {total_traditional} rules")

# %% [markdown]
# ### 5. Save Traditional Results

# %%
with open(data_dir / "rule_classes_traditional.json", 'w') as f:
    json.dump(rules_traditional, f, indent=2)
print(f"Saved traditional rules to {data_dir}")

# %% [markdown]
# ---
# ## Direct Comparison: Same Document, Both Methods

# %%
def count_rules(rules_list):
    return sum(len(rc.get('rule_properties', {})) for rc in rules_list)

def page_ref_stats(rules_list):
    total, with_page = 0, 0
    for rc in rules_list:
        for rd in rc.get('rule_properties', {}).values():
            total += 1
            if rd.get('page', '').strip(): with_page += 1
    return with_page, total

def key_stats(rules_list):
    generic, descriptive = 0, 0
    for rc in rules_list:
        for k in rc.get('rule_properties', {}).keys():
            if k.startswith('rule_') and k[5:].isdigit(): generic += 1
            else: descriptive += 1
    return descriptive, generic

a_count = count_rules(rules_agentic)
t_count = count_rules(rules_traditional)
a_pg, a_pg_tot = page_ref_stats(rules_agentic)
t_pg, t_pg_tot = page_ref_stats(rules_traditional)
a_desc, a_gen = key_stats(rules_agentic)
t_desc, t_gen = key_stats(rules_traditional)

print(f"Comparing: {Path(POLICY_PDF_PATH).name}")
print("=" * 60)

print(f"\n  TRADITIONAL")
print(f"  Time: {traditional_time:.1f}s | Classes: {len(rules_traditional)} | Rules: {t_count}")
print(f"  Page refs: {t_pg}/{t_pg_tot} | Keys: {t_desc} descriptive, {t_gen} generic")

print(f"\n  AGENTIC")
print(f"  Time: {agentic_time:.1f}s | Classes: {len(rules_agentic)} | Rules: {a_count}")
print(f"  Page refs: {a_pg}/{a_pg_tot} | Keys: {a_desc} descriptive, {a_gen} generic")

print("\n" + "=" * 60)
print("COMPARISON SUMMARY")
print("=" * 60)

if traditional_time > 0:
    spd = ((traditional_time - agentic_time) / traditional_time) * 100
    print(f"Speed: Agentic is {spd:.1f}% {'faster' if spd > 0 else 'slower'}")
    print(f"  Traditional: {traditional_time:.1f}s | Agentic: {agentic_time:.1f}s")

rd = a_count - t_count
print(f"\nRules: Agentic extracted {rd:+d} rules")
print(f"  Traditional: {t_count} | Agentic: {a_count}")

print(f"\nSchema Compliance:")
print(f"  Traditional: Manual JSON parsing + validation retries")
print(f"  Agentic: Pydantic model enforced via tool-based validation (guaranteed schema)")

print(f"\nKey Quality:")
print(f"  Traditional: {t_desc} descriptive, {t_gen} generic")
print(f"  Agentic: {a_desc} descriptive, {a_gen} generic")

print("\nKEY ADVANTAGES OF AGENTIC RULE DISCOVERY:")
advs = []
if rd > 0: advs.append(f"Better rule coverage (+{rd} rules)")
if a_gen == 0 and t_gen > 0: advs.append("All descriptive rule names (no generic rule_N)")
if a_pg > t_pg: advs.append(f"Better page references ({a_pg} vs {t_pg})")
advs.append("Self-correcting with Pydantic schema validation")
advs.append("Handles large docs via buffer/patch tools")
advs.append("Guaranteed output format, no JSON parsing failures")
for a in advs: print(f"  - {a}")

# %%
# Side-by-side: first 3 rules from each method
def sample_rules(rules_list, n=3):
    out = []
    for rc in rules_list:
        for rid, rd in rc.get('rule_properties', {}).items():
            out.append((rid, rd))
            if len(out) >= n: return out
    return out

print("TRADITIONAL (first 3):")
for rid, rd in sample_rules(rules_traditional, 3):
    print(f"  [{rid}] (p.{rd.get('page','?')}) {rd.get('description','')[:100]}")

print("\nAGENTIC (first 3):")
for rid, rd in sample_rules(rules_agentic, 3):
    print(f"  [{rid}] (p.{rd.get('page','?')}) {rd.get('description','')[:100]}")

# %% [markdown]
# ## Summary

# %%
print("=== Rules Discovery Agentic Comparison Complete ===")
print(f"Document: {Path(POLICY_PDF_PATH).name}")
print(f"Agentic: {len(rules_agentic)} classes, {count_rules(rules_agentic)} rules in {agentic_time:.1f}s")
print(f"Traditional: {len(rules_traditional)} classes, {count_rules(rules_traditional)} rules in {traditional_time:.1f}s")
print(f"Data saved to: .data/step_rules_discovery_agentic/")
print("\nNext: Use these rules with RuleValidationService to validate transactions")
